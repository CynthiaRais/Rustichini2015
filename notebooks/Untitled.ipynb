# %%
import dotdot
import model
import graphs
import settings
import data_analysis
import bokeh.plotting
# %matplotlib inline

# %%
#figure 4
ΔA = 20
ΔB = 20
w_p= 1.75
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
quantity_a, quantity_b, x_min_list, x_max_list = setting.quantity_juice()
result_one_trial = setting.result_trials()

m=model.Model(n = number_of_trials, ΔA = ΔA, ΔB = ΔB, w_p = w_p,
              x_min_list = setting.x_min_list, x_max_list = setting.x_max_list)
              
print("taille quantity", len(setting.quantity_a), max(setting.quantity_a))

for i in range(number_of_trials):
    print("trial", i)
    result_one_trial[(quantity_a[i], quantity_b[i])].append(m.one_trial(x_a = quantity_a[i], x_b = quantity_b[i])) 

     
    
#m.save_history('data.pickle')
print(len(result_one_trial[(1,1)]), len(result_one_trial[(10,9)]))
analysis = data_analysis.data_analysis_cells(result_one_trial = result_one_trial.copy())
bokeh.plotting.output_notebook()
g=graph.Graph(ΔA=ΔA, ΔB = ΔB, analysis=analysis)

figure_4A = g.firing_time_ov(analysis.average_firing_rate_B_ov())
bokeh.plotting.show(figure_4A)

figure_4B = g.tuning_curve_ov(analysis.tuning_curve_ov())
figure_4B.show()

figure_4C = g.firing_specific_set_ov(analysis.ov_choiceA, analysis.ov_choiceB, analysis.poucentage_B())
figure_4C.show()

figure_4D = g.firing_offer_B(analysis.average_firing_offerB_ov())
figure_4D.show()

figure_4E = g.firing_time_cjb(analysis.average_firing_rate_cj())
figure_4E.show()

figure_4F = g.tuning_curve_cj(analysis.tuning_curve_cjb())
figure_4F.show()

figure_4G = g.firing_specific_set_cjb(analysis.cjb_choiceA, analysis.cjb_choiceB, analysis.pourcentage_B())
figure_4G.show()

figure_4H = g.firing_choice(analysis.firing_H_A, analysis.firing_H_B)
figure_4H.show()

figure_4I = g.firing_time_cv(analysis.average_firing_rate_cv())
figure_4I.show()

figure_4J = g.tuning_curve_cv(analysis.tuning_curve_cv())
figure_4J.show()

figure_4K = g.firing_specific_set_cv(analysis.cv_choiceA, analysis.cv_choiceB, analysis.pourcentage_B())
figure_4K.show()

figure_4L = firing_chosen_value(analysis.X_A, analysis.X_B, analysis.Y_A, analysis.Y_B)
figure_4L.show()
# Out:
# j'ai init le model
# taille quantity 4000 20
# trial 0
# trial 1
# trial 2
# trial 3
# trial 4
# trial 5
# trial 6
# trial 7
# trial 8
# trial 9
# trial 10
# trial 11
# trial 12
# trial 13
# trial 14
# trial 15
# trial 16
# trial 17
# trial 18
# trial 19
# trial 20
# trial 21
# trial 22
# trial 23
# trial 24
# trial 25
# trial 26
# trial 27
# trial 28
# trial 29
# trial 30
# trial 31
# trial 32
# trial 33
# trial 34
# trial 35
# trial 36
# trial 37
# trial 38
# trial 39
# trial 40
# trial 41
# trial 42
# trial 43
# trial 44
# trial 45
# trial 46
# trial 47
# trial 48
# trial 49
# trial 50
# trial 51
# trial 52
# trial 53
# trial 54
# trial 55
# trial 56
# trial 57
# trial 58
# trial 59
# trial 60
# trial 61
# trial 62
# trial 63
# trial 64
# trial 65
# trial 66
# trial 67
# trial 68
# trial 69
# trial 70
# trial 71
# trial 72
# trial 73
# trial 74
# trial 75
# trial 76
# trial 77
# trial 78
# trial 79
# trial 80
# trial 81
# trial 82
# trial 83
# trial 84
# trial 85
# trial 86
# ...

# %%
#figure 4
ΔA = 20
ΔB = 20
w_p= 1.75
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
quantity_a, quantity_b, x_min_list, x_max_list = setting.quantity_juice()
result_one_trial = setting.result_trials()

m=model.Model(n = number_of_trials, ΔA = ΔA, ΔB = ΔB, w_p = w_p,
              x_min_list = setting.x_min_list, x_max_list = setting.x_max_list)
              
print("taille quantity", len(setting.quantity_a), max(setting.quantity_a))

for i in range(number_of_trials):
    print("trial", i)
    result_one_trial[(quantity_a, quantity_b)].append(m.one_trial(x_a = quantity_a[i], x_b = quantity_b[i])) 

print(result_one_trial)        
    
#m.save_history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = result_one_trial)
bokeh.plotting.output_notebook()
g=graph.Graph(ΔA=ΔA, ΔB = ΔB, analysis=analysis)

figure_4A = g.firing_time_ov(analysis.average_firing_rate_B_ov())
bokeh.plotting.show(figure_4A)

figure_4B = g.tuning_curve_ov(analysis.tuning_curve_ov())
figure_4B.show()

figure_4C = g.firing_specific_set_ov(analysis.ov_choiceA, analysis.ov_choiceB, analysis.poucentage_B())
figure_4C.show()

figure_4D = g.firing_offer_B(analysis.average_firing_offerB_ov())
figure_4D.show()

figure_4E = g.firing_time_cjb(analysis.average_firing_rate_cj())
figure_4E.show()

figure_4F = g.tuning_curve_cj(analysis.tuning_curve_cjb())
figure_4F.show()

figure_4G = g.firing_specific_set_cjb(analysis.cjb_choiceA, analysis.cjb_choiceB, analysis.pourcentage_B())
figure_4G.show()

figure_4H = g.firing_choice(analysis.firing_H_A, analysis.firing_H_B)
figure_4H.show()

figure_4I = g.firing_time_cv(analysis.average_firing_rate_cv())
figure_4I.show()

figure_4J = g.tuning_curve_cv(analysis.tuning_curve_cv())
figure_4J.show()

figure_4K = g.firing_specific_set_cv(analysis.cv_choiceA, analysis.cv_choiceB, analysis.pourcentage_B())
figure_4K.show()

figure_4L = firing_chosen_value(analysis.X_A, analysis.X_B, analysis.Y_A, analysis.Y_B)
figure_4L.show()

# %%
#figure 5
ΔA = 20
ΔB = 20
w_p=1.75
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, ΔA = ΔA, ΔB = ΔB, w_p = w_p,
              x_min_list = setting.x_min_list, x_max_list = setting.x_max_list)
for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(ΔA=ΔA, ΔB = ΔB, analysis=analysis)


g.show()

# %%
#figure 6
w_p=1.55
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, 
              ΔA         = ΔA, 
              ΔB         = ΔB, 
              w_p        = w_p,
              x_min_list = setting.x_min_list, 
              x_max_list = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(ΔA       = ΔA, 
              ΔB       = ΔB, 
              analysis = analysis)

figure_6A = g.firing_time_cjb()
figure_6A.show()

figure_6B = g.tuning_curve_cj()
figure_6B.show()

figure_6C = g.firing_time_cv()
figure_6C.show()

figure_6D = g.firing_chosen_value()
figure_6D.show()

# %%
#figure 6
w_p=1.70
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n          = number_of_trials, 
              ΔA         = ΔA, 
              ΔB         = ΔB, 
              w_p        = w_p,
              x_min_list = setting.x_min_list, 
              x_max_list = setting.x_max_list)
for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(ΔA       = ΔA, 
              ΔB       = ΔB, 
              analysis = analysis)

figure_6E = g.firing_time_cjb()
figure_6E.show()

figure_6F = g.tuning_curve_cj()
figure_6F.show()

figure_6G = g.firing_time_cv()
figure_6G.show()

figure_6H = g.firing_chosen_value()
figure_6H.show()

# %%
#figure 6
w_p=1.80
number_of_trials = 4000
setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n          = number_of_trials, 
              ΔA         = ΔA, 
              ΔB         = ΔB, 
              w_p        = w_p,
              x_min_list = setting.x_min_list, 
              x_max_list = setting.x_max_list)
for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(ΔA       = ΔA, 
              ΔB       = ΔB, 
              analysis = analysis)

figure_6I = g.firing_time_cjb()
figure_6I.show()

figure_6J = g.tuning_curve_cj()
figure_6J.show()

figure_6K = g.firing_time_cv()
figure_6K.show()

figure_6L = g.firing_chosen_value()
figure_6L.show()

# %%
#figure 7
number_of_trials = 4000

m=model.Model(n   = number_of_trials, 
              ΔA  = ΔA, 
              ΔB  = ΔB, 
              w_p = w_p)
for i in range(number_of_trials +1):
    m.trial()
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graphs.tuning_curve(m.history)
g.show()

# %%
#figure 8
number_of_trials = 4000

m=model.Model(n   = number_of_trials, 
              ΔA  = ΔA, 
              ΔB  = ΔB, 
              w_p = w_p)

for i in range(number_of_trials +1):
    m.trial()
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graphs.tuning_curve(m.history)
g.show()

# %%
#figure 9 B1 - D1
ΔA = 15
ΔB = 15
w_p = 1.75
number_of_trials = 4000
ΔJ = 30

setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, 
              ΔA            = ΔA, 
              ΔB            = ΔB, 
              w_p           = w_p,
              r_o           = r_o,
              J_ampa_rec_in = J_ampa_rec_in, 
              J_nmda_rec_in = J_nmda_rec_in, 
              J_gaba_rec_in = J_gaba_rec_in,
              ΔJ            = ΔJ,
              x_min_list    = setting.x_min_list, 
              x_max_list    = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(      ΔA = ΔA, 
                    ΔB = ΔB, 
              analysis = analysis)

# %%
#figure 9 B2 - D2
ΔA = 15
ΔB = 15
w_p = 1.85
number_of_trials = 4000
ΔJ = 30

setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, 
              ΔA            = ΔA, 
              ΔB            = ΔB, 
              w_p           = w_p,
              r_o           = r_o,
              J_ampa_rec_in = J_ampa_rec_in, 
              J_nmda_rec_in = J_nmda_rec_in, 
              J_gaba_rec_in = J_gaba_rec_in,
              ΔJ            = ΔJ,
              x_min_list    = setting.x_min_list, 
              x_max_list    = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(      ΔA = ΔA, 
                    ΔB = ΔB, 
              analysis = analysis)

# %%
# figure 9 B3 - D3
#figure 9 B2 - D2
ΔA = 15
ΔB = 15
w_p = 1.75
number_of_trials = 4000
ΔJ = 15

setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, 
              ΔA            = ΔA, 
              ΔB            = ΔB, 
              w_p           = w_p,
              r_o           = r_o,
              J_ampa_rec_in = J_ampa_rec_in, 
              J_nmda_rec_in = J_nmda_rec_in, 
              J_gaba_rec_in = J_gaba_rec_in,
              ΔJ            = ΔJ,
              x_min_list    = setting.x_min_list, 
              x_max_list    = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(      ΔA = ΔA, 
                    ΔB = ΔB, 
              analysis = analysis)

# %%
#figure 10
ΔA = 20
ΔB = 20
w_p=1.65
number_of_trials = 4000
J_ampa_rec_in = -0.00198  # 0.9 * J_ampa_rec_in
J_nmda_rec_in = -0.000751014 # 0.9 * J_nmda_rec_in
J_gaba_rec_in = 0.0144 # 0.8 * J_gaba_rec_in
r_o = 6

setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n = number_of_trials, 
              ΔA            = ΔA, 
              ΔB            = ΔB, 
              w_p           = w_p,
              r_o           = r_o,
              J_ampa_rec_in = J_ampa_rec_in, 
              J_nmda_rec_in = J_nmda_rec_in, 
              J_gaba_rec_in = J_gaba_rec_in,
              x_min_list    = setting.x_min_list, 
              x_max_list    = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(      ΔA = ΔA, 
                    ΔB = ΔB, 
              analysis = analysis)

figure_10A = g.firing_time_ov()
figure_10A.show()

figure_10B = g.firing_time_cjb()
figure_10B.show()

figure_10C = g.tuning_curve_cj()
figure_10C.show()

figure_10D = g.firing_time_cv()
figure_10D.show()

figure_10E = g.firing_chosen_value()
figure_10E.show()

# %%
#figure 10
ΔA = 20
ΔB = 20
w_p=1.65
number_of_trials = 4000
J_ampa_rec_in = -0.00198  # 0.9 * J_ampa_rec_in
J_nmda_rec_in = -0.000751014 # 0.9 * J_nmda_rec_in
J_gaba_rec_in = 0.0144 # 0.8 * J_gaba_rec_in
δ_J_stim =(1.2, 1)
r_o = 6

setting = settings.Presetting(ΔA = ΔA, ΔB = ΔB)
setting.quantity_juice()

m=model.Model(n             = number_of_trials, 
              ΔA            = ΔA, 
              ΔB            = ΔB, 
              w_p           = w_p,
              r_o           = r_o,
              J_ampa_rec_in = J_ampa_rec_in, 
              J_nmda_rec_in = J_nmda_rec_in, 
              J_gaba_rec_in = J_gaba_rec_in,
              δ_J_stim      = δ_J_stim, 
              x_min_list    = setting.x_min_list, 
              x_max_list    = setting.x_max_list)

for i in range(number_of_trials +1):
    m.trial(x_a = setting.quantity_a[i], 
            x_b = setting.quantity_b[i])
    
m.save.history('data.pickle')

analysis = data_analysis.data_analysis_cells(result_one_trial = m.history)
g=graph.Graph(ΔA       = ΔA, 
              ΔB       = ΔB, 
              analysis = analysis)

figure_10A = g.firing_time_ov()
figure_10A.show()

figure_10B = g.firing_time_cjb()
figure_10B.show()

figure_10C = g.tuning_curve_cj()
figure_10C.show()

figure_10D = g.firing_time_cv()
figure_10D.show()

figure_10E = g.firing_chosen_value()
figure_10E.show()
